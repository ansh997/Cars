# %% [markdown]
# # Predicting Depreciation in Price of car using ML

# %% [raw]
# You need to develop a model to predict the depreciation of any car given the parameters which are available in the file. This data contains all the parameters of cars that will be available for predicting depreciation of a used car. It also contains the current on road price of a new car, used car price and depreciation % of the car.You may need to remove the outliers etc. Final output of the model should be depreciation % given the make, model, variant, color, number of owners, Kms driven, body type, transmission, fuel type and on road price.

# %%
#importing important modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

% matplotlib inline

# %%
# load the data set

data = pd.read_csv('./cars.csv')
data.head()
# Out:
#                                      MMV     Make                Model  \
# 0                   HyundaiI10Sportz 1.2  Hyundai                  I10
# 1                HyundaiI20Magna (O) 1.2  Hyundai                  I20
# 2                   HyundaiI20Sportz 1.2  Hyundai                  I20
# 3  HyundaiNeo Fluidic Elantra1.6SxAtCrdi  Hyundai  Neo Fluidic Elantra
# 4                   HyundaiSantro XingXo  Hyundai          Santro Xing
#
#          Variant       Type Fuel Type  Age Transmission   Color       Kms  \
# 0     Sportz 1.2  Hatchback    Petrol    3       Manual   White    12,000
# 1  Magna (O) 1.2  Hatchback    Petrol    9       Manual   Beige    68,000
# 2     Sportz 1.2  Hatchback    Petrol    8       Manual   White    31,143
# 3    1.6SxAtCrdi      Sedan    Diesel    2    Automatic  Silver     6,000
# 4             Xo  Hatchback    Petrol   11       Manual  Golden  1,00,000
#
#    No of Owner  Heath score  price score  on road price  Current Price   Dep
# ...

# %%
# check for NaN values or na

data.isna().values.any()
# Out:
# False

# %% [raw]
# THere are no null values in data. Check the propertirs of dataset.

# %%
data.describe()
# Out:
#                Age  No of Owner  Heath score  price score  on road price  \
# count  3879.000000  3879.000000  3879.000000  3879.000000   3.879000e+03
# mean      7.274040     1.226605     5.697602     6.849368   9.381425e+05
# std       2.695272     0.549230     1.620505     1.926978   5.841469e+05
# min       1.000000     1.000000     3.300000     3.200000   2.372750e+05
# 25%       5.000000     1.000000     4.500000     5.200000   5.378500e+05
# 50%       7.000000     1.000000     5.000000     6.800000   7.819280e+05
# 75%       9.000000     1.000000     6.800000     8.400000   1.120298e+06
# max      12.000000     6.000000     9.900000     9.900000   1.095466e+07
#
#        Current Price          Dep
# count   3.879000e+03  3879.000000
# mean    4.130298e+05    54.342743
# std     3.030802e+05    17.236117
# min     5.192000e+04     2.100000
# 25%     2.335180e+05    42.200000
# 50%     3.291520e+05    55.300000
# 75%     4.877280e+05    67.250000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3879 entries, 0 to 3878
# Data columns (total 16 columns):
# MMV              3879 non-null object
# Make             3879 non-null object
# Model            3879 non-null object
# Variant          3879 non-null object
# Type             3879 non-null object
# Fuel Type        3879 non-null object
# Age              3879 non-null int64
# Transmission     3879 non-null object
# Color            3879 non-null object
# Kms              3879 non-null object
# No of Owner      3879 non-null int64
# Heath score      3879 non-null float64
# price score      3879 non-null float64
# on road price    3879 non-null int64
# Current Price    3879 non-null int64
# Dep              3879 non-null float64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 485.0+ KB

# %% [raw]
# There are 7 numeric and 9 string based columns. None of them are null.

# %%
data.columns.values
# Out:
# array(['MMV', 'Make', 'Model', 'Variant', 'Type', 'Fuel Type', 'Age',
#        'Transmission', 'Color', 'Kms', 'No of Owner', 'Heath score',
#        'price score', 'on road price', 'Current Price', 'Dep'], dtype=object)

# %% [raw]
# In the given data MMV is make model variant hence we can drop it while doing feature engineering because we already have separate Makeodel and  variant columns.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import seaborn as sns
sns.set_context('talk', font_scale=1.2);

# %%
sns.pairplot(data, hue = 'Fuel Type');

# %% [raw]
# There are few clear outliers espeially when price range is concerned. Data is highly skewed.

# %%
data['log_currentprice'] = np.log10(data['Current Price'])
data['log_on_road_price'] = np.log10(data['on road price'])

data = data.drop(columns = ['Current Price', 'on road price'])

# %%
np.argmax(data['log_on_road_price'])
# Out:
# /home/ansh/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'argmax' is deprecated. Use 'idxmax' instead. The behavior of 'argmax' will be corrected to return the positional maximum in the future. Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# 3724

# %%
data.drop(data.index[3724])
# Out:
#                                           MMV           Make  \
# 0                        HyundaiI10Sportz 1.2        Hyundai
# 1                     HyundaiI20Magna (O) 1.2        Hyundai
# 2                        HyundaiI20Sportz 1.2        Hyundai
# 3       HyundaiNeo Fluidic Elantra1.6SxAtCrdi        Hyundai
# 4                        HyundaiSantro XingXo        Hyundai
# 5         HyundaiGrand I10Asta 1.2 Kappa VTVT        Hyundai
# 6                            HyundaiAccentGLS        Hyundai
# 7                             HyundaiI10Magna        Hyundai
# 8                               HyundaiI10Era        Hyundai
# 9                  HyundaiCreta1.6Sx+AtDiesel        Hyundai
# 10          HyundaiElite I20Asta 1.4 CRDI (O)        Hyundai
# 11                        HyundaiI10Magna 1.2        Hyundai
# 12                              HyundaiI10Era        Hyundai
# 13                             HyundaiVernaXi        Hyundai
# ...

# %%
plt.rcParams['font.size'] = 40
sns.pairplot(data, hue = 'Fuel Type');

# %% [raw]
# Age and Depriciation has positive correlation as it is to be expected. There are no such visible outliers.
# Age and current price has negative correlation as it is to be expected. There are few visible outliers.
# Strangely though, Age and on road price does not have have any correlation. There are few visible outliers.

# %%
sns.pairplot(data, hue = 'Fuel Type', vars=["Dep", "log_currentprice", "log_on_road_price", "Age"]);

# %% [raw]
# Now to clearly understand the corrleation between the features. We will plot a heatmap.

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )

# %%
plot_correlation_map(data)

# %% [raw]
# Squares with reddish naad bluish tinge have maximum correlation.

# %% [markdown]
# ### Data Preprocessing

# %%
# Importing LabelEncoder and initializing it
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for col in data.columns.values:
       # Encoding only categorical variables
       if data[col].dtypes=='object':
       # Using whole data to form an exhaustive list of levels
           data2=data[col].append((data[col]))
           le.fit(data2.values)
           data[col]=le.transform(data[col])
           #data[col]=le.transform(X_test[col])

# %%
data.head()
# Out:
#    MMV  Make  Model  Variant  Type  Fuel Type  Age  Transmission  Color   Kms  \
# 0  193     1     35      347     1          3    3             2     31   119
# 1  212     1     36      305     1          3    9             2      0  1164
# 2  218     1     36      347     1          3    8             2     31   368
# 3  225     1     44       61     4          1    2             1     24  1019
# 4  235     1     51      442     1          3   11             2     10     0
#
#    No of Owner  Heath score  price score   Dep  log_currentprice  \
# 0            1          8.5          8.8  37.1          5.529369
# 1            1          5.0          7.3  69.2          5.276921
# 2            1          6.2          4.6  48.8          5.541040
# 3            1          8.5          7.9  26.9          6.211988
# 4            2          4.3          9.9  81.0          4.935709
#
#    log_on_road_price
# 0           5.730661
# 1           5.788071
# 2           5.831460
# ...

# %% [markdown]
# ## Without removing outliers

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
y = data['Dep']
X = data[['MMV', 'Make', 'Model', 'Variant', 'Type', 'Fuel Type', 'Age',
       'Transmission', 'Color', 'Kms', 'No of Owner', 'Heath score',
       'price score', 'log_currentprice', 'log_on_road_price']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pr = lr.predict(X_test)
y_pr
# Out:
# array([ 31.65726891,  74.81539106,  63.79939777, ...,  47.51637297,
#         41.45907707,  63.16810004])

# %%
rmse = mean_squared_error(y_test, y_pr)
#r2 = r2_score(y_test, y_pr)
rmse
# Out:
# 16.574271801315689

# %%
r2 = r2_score(y_test, y_pr)
r2
# Out:
# 0.94455682663367113

# %% [markdown]
# ### Using XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.7,
                max_depth = 7, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 6.720959

# %% [markdown]
# ### k-fold Cross Validation using XGBoost

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=1000,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
cv_results.head()
# Out:
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=5
# ...

# %%
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# 999    3.411777
# Name: test-rmse-mean, dtype: float64

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [11, 11]
plt.show()

# %% [raw]
# Above plot shows which feature contributed more in the process.

# %% [markdown]
# ## Removing outliers

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(data))
print(z)
# Out:
# [[ 0.54557499  0.43090793  0.02550596 ...,  1.00051339  0.02739916
#    0.83779054]
#  [ 0.42840511  0.43090793  0.07755101 ...,  0.86209512  1.03099862
#    0.57302022]
#  [ 0.3914041   0.43090793  0.07755101 ...,  0.3216187   0.01899877
#    0.37291861]
#  ...,
#  [ 1.02696815  0.60535485  1.3786771  ...,  0.78001768  0.70131429
#    1.49537051]
#  [ 0.47195292  0.60535485  0.49494448 ...,  0.59433708  0.89245284
#    0.46600563]
#  [ 0.44728558  0.60535485  0.49494448 ...,  1.24421918  0.95262258
#    0.16937036]]

# %%
print(np.where(z > 3))
# Out:
# (array([  62,   86,   88,  113,  117,  135,  159,  182,  246,  344,  363,
#         519,  582,  632,  635,  656,  665,  667,  712,  733,  839,  862,
#         924, 1075, 1146, 1180, 1211, 1213, 1350, 1403, 1508, 1529, 1538,
#        1572, 1579, 1594, 1614, 1620, 1630, 1652, 1678, 1686, 1687, 1690,
#        1721, 1785, 1822, 1826, 1854, 1872, 1883, 1970, 1980, 1990, 2036,
#        2047, 2047, 2081, 2093, 2096, 2136, 2141, 2143, 2178, 2179, 2203,
#        2206, 2215, 2235, 2257, 2273, 2297, 2305, 2308, 2313, 2324, 2334,
#        2352, 2358, 2411, 2425, 2437, 2441, 2470, 2483, 2485, 2490, 2500,
#        2521, 2585, 2620, 2621, 2658, 2733, 2770, 2773, 2785, 2790, 2822,
#        2837, 2941, 2943, 2953, 2977, 3000, 3052, 3064, 3126, 3170, 3199,
#        3303, 3419, 3429, 3457, 3470, 3474, 3562, 3585, 3608, 3611, 3614,
#        3658, 3662, 3668, 3679, 3681, 3684, 3685, 3692, 3695, 3706, 3709,
# ...

# %%
data.shape
# Out:
# (3879, 16)

# %%
data_o = data[(z < 3).all(axis=1)]

# %%
data_o.shape
# Out:
# (3742, 16)

# %%
sns.pairplot(data_o, hue = 'Fuel Type', vars = ['Age', 'Heath score',
       'price score', 'log_currentprice', 'log_on_road_price', 'Dep']);

# %% [raw]
# Now the outliers has been removed.

# %% [markdown]
# ## Linear Regression

# %%
Y = data_o['Dep']
X_ = data_o[['MMV', 'Make', 'Model', 'Variant', 'Type', 'Fuel Type', 'Age',
       'Transmission', 'Color', 'Kms', 'No of Owner', 'Heath score',
       'price score', 'log_currentprice', 'log_on_road_price']]
x_train, x_test, Y_train, Y_test = train_test_split(X_, Y, test_size=0.33, random_state=42)

# %%
lr.fit(x_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred = lr.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(Y_test, pred))
#r2 = r2_score(y_test, y_pr)
rmse
# Out:
# 3.6868267356005018

# %%
r2 = r2_score(Y_test, pred)
print((r2*100))
# Out:
# 95.1873776843

# %% [raw]
# By removing outliers efficiency has improved

# %% [markdown]
# ## Using XGBoost

# %%
data_dmatrix = xgb.DMatrix(data=X_,label=Y)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.7,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(x_train, Y_train)

preds = xg_reg.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(Y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 7.283693

# %%
r2 = r2_score(Y_test, preds)
print((r2*100))
# Out:
# 81.2163693209

# %% [markdown]
# ## k-fold Cross Validation using XGBoost¶

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=1000,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
cv_results.head()
# Out:
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [21:01:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# ...

# %%
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# 999    3.342967
# Name: test-rmse-mean, dtype: float64

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [11, 11]
plt.show()

# %% [raw]
# Above mentioned models predicts the depreciation in price of car with great efficiencies. Any one of these models can be used to predict the depreciation given other features.
